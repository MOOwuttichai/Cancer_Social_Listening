# %% [markdown]
# <a href="https://colab.research.google.com/github/MOOwuttichai/Cancer_Social_Listening/blob/main/descriptive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from collections import OrderedDict
import matplotlib as mpl
import numpy as np
from sklearn.cluster import KMeans
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#creating a list
rand = [2,3,6,1,8,4,9,0]
#printing max element
print(max(rand))
# Out:
# 9

# %%
x=[1,2,3,4,5]
x
# Out:
# [1, 2, 3, 4, 5]

# %%
# Remove the variable 'max' that is hiding the built-in function
del min

# Now you can use the built-in 'max' function
max(x)
# Out:
# 710

# %%
x=data[data.columns[4]].tolist()
print(max(x))
# Out:
# 710

# %%
max_v = []
min_v = []
avg_v = []
_ = ['like','จำนวนการตอบกลับ','ความยาว']
data = pd.read_csv("/content/drive/MyDrive/Carbon/data/data_commentsFB_docter.csv", encoding='utf-8-sig')

for i in range(len(data.columns)):
  if i >= 2:
    max_v.append(max(data[data.columns[i]].tolist()))
    min_v.append(min(data[data.columns[i]].tolist()))
    avg_v.append(np.mean(data[data.columns[i]].tolist()))
descriptive = pd.DataFrame()
descriptive['_'] = _
descriptive['max'] = max_v
descriptive['min'] = min_v
descriptive['avg'] = avg_v
descriptive.set_index('_', inplace = True)
descriptive
# Out:
#                  max  min        avg
# _
# like              94    0   2.024648
# จำนวนการตอบกลับ  233    0   4.866197
# ความยาว          710    1  63.545775

# %%
name_cancar = ['มะเร็งกระเพาะปัสสวะ','มะเร็งเยื่อบุโพรงมดลูก','มะเร็งปากมดลูก','มะเร็งเม็ดเลือดขาว','มะเร็งตับ','มะเร็งตับอ่อน','มะเร็งต่อมลูกหมาก','มะเร็งกระเพาะปัสสาวะ','มะเร็งกระเพาะอาหาร'
,'มะเร็งหลอดอาหาร','มะเร็งเต้านม','มะเร็งปอด','มะเร็งลำไส้ใหญ่','มะเร็งรังไข่','มะเร็งช่องปาก','มะเร็งต่อมไทรอยด์','มะเร็งต่อมน้ำเหลือง','มะเร็งสมอง','มะเร็งผิวหนัง','มะเร็งลำไส้'
,'มะเร็งท่อน้ำดี',"มะเร็งลำไส้ใหญ่และทวารหนัก","มะเร็งผิวหนังชนิดเมลาโนมา","มะเร็งต่อมน้ำเหลืองชนิดนอนฮอดจ์กิน","มะเร็งเม็ดเลือดขาวชนิดเฉียบพลัน","มะเร็งกระดูก","มะเร็งสมองและระบบประสาทกลาง","มะเร็งไต",
"มะเร็งมดลูก","มะเร็งถุงน้ำดี","มะเร็งกระดูกสันหลัง","มะเร็งลูกตา","มะเร็งเยื่อบุช่องคลอด","มะเร็งเยื่อบุอวัยวะเพศชาย","มะเร็งเยื่อบุอวัยวะเพศหญิง","มะเร็งต่อมหมวกไต","มะเร็งต่อมน้ำลาย","มะเร็งถุงน้ำรังไข่"
]

# %%
cancer_names_en = [
    "Bladder cancer",
    "Endometrial cancer",
    "Cervical cancer",
    "Leukemia",
    "Liver cancer",
    "Pancreatic cancer",
    "Prostate cancer",
    "Stomach cancer",
    "Esophageal cancer",
    "Breast cancer",
    "Lung cancer",
    "Colorectal cancer",
    "Ovarian cancer",
    "Oral cancer",
    "Thyroid cancer",
    "Lymphoma",
    "Brain cancer",
    "Skin cancer",
    "Intestinal cancer",  # More general term
    "Bile duct cancer",
    "Colorectal cancer",  # More specific term
    "Melanoma",
    "Hodgkin lymphoma",
    "Acute leukemia",
    "Bone cancer",
    "Central nervous system cancer",
    "Kidney cancer",
    "Uterine cancer",  # More general term
    "Gallbladder cancer",
    "Spinal cord cancer",
    "Eye cancer",
    "Vaginal cancer",
    "Penile cancer",
    "Vulvar cancer",
    "Adrenal gland cancer",
    "Salivary gland cancer",
    "Ovarian cyst cancer",
]

# %%
symptoms = {
    "อ่อนเพลีย":["อ่อนเพลีย"],
    'เหนื่อยง่าย':['เหนื่อยง่าย','เหนื่อย','เพลีย','เหนื่อยหอบ'],
    'คันเนื้อคันตัว':['คันเนื้อคันตัว','คัน','คันตัว','คันตามตัว'],
    'มีอาการร้อน':['ร้อน','อาการรัอน','ตัวร้อน'],
    'อาการเจ็บปวด':['เจ็บปวด','เจ็บ','อาการเจ็บปวด'],
    'อาการชา':['อาการชา','ชา'],
    "เบื่ออาหาร":["เบื่ออาหาร"],
    "น้ำหนักลดโดยไม่ทราบสาเหตุ":["น้ำหนักลดโดยไม่ทราบสาเหตุ",'น้ำหนักลด','น้ำหนักลดลงเร็วมาก'],
    "ไข้เรื้อรัง":["ไข้เรื้อรัง",'ไข้','เป็นไข้'],
    "เหงื่อออกตอนกลางคืน":["เหงื่อออกตอนกลางคืน","เหงื่อออกตอนดึก",'เหงื่อออก'],
    "ปวดเมื่อย":["ปวดเมื่อยตามร่างกาย","เมื่อย"],
    "บวมหรือต่อมน้ำเหลืองโต":["บวมหรือต่อมน้ำเหลืองโต","ต่อมน้ำเหลืองโต","บวมน้ำเหลืองโต"],
    "ปวดท้อง":["ปวดท้อง"],
    "เจ็บคอ":["เจ็บคอ"],
    'ปวดใต้รักแร้':['ปวดใต้รักแร้','ปวดรักแร้'],
    'ปวดเอว':['ปวดเอว'],
    'ผิวคล้ำผิดปกติ':['ผิวคล้ำ'],
    'เจ็บเต้านม':['เจ็บเต้านม','เจ็บเต้า','เจ็บนม'],
    "ท้องอืด":["ท้องอืด",'อาการอืดท้อง','อืด'],
    "ท้องผูกเรื้อรัง":["ท้องผูกเรื้อรัง","ท้องผูก"],
    "อาหารไม่ย่อย":["อาหารไม่ย่อย"],
    "กลืนลำบาก":["กลืนลำบาก","กลืนอาหารลำบาก","กลืนยาก"],
    "ปวดท้องเรื้อรัง":["ปวดท้องเรื้อรัง"],
    "อาเจียนอาจมีเลือด":["อาเจียนเป็นเลือด","อาเจียน",'อ้วก'],
    "อุจจาระอาจมีเลือด":["อุจจาระเป็นเลือด","อึเป็นเลือด","ขี้เป็นเลือด",'อุจจาระ','ขี้','ถ่าย','ถ่ายเป็นเลือด'],
    "ไอเรื้อรัง":["ไอเรื้อรัง",'ไอ','ไอต่อเนื่อง','ไอแห้ง'],
    "ไอเป็นเลือด":["ไอเป็นเลือด"],
    "เสียงแหบ":["เสียงแหบ"],
    "หายใจลำบาก":["หายใจลำบาก","หายใจไม่อิ่ม",'หายใจ'],
    "เจ็บหรือเเน่นหน้าอก":["เจ็บหน้าอก",'เเน่นหน้าอก'],
    "เลือดออกผิดปกติจากช่องคลอด":["เลือดออกผิดปกติจากช่องคลอด","เลือดออกจากช่องคลอด","เลือดออกผิดปกติจากอวัยวะเพศ","เลือดออกจากอวัยวะเพศ",'เลือดไหล'],
    "ตกขาวผิดปกติ":["ตกขาวผิดปกติ","ตกขาว"],
    "ปัสสาวะบ่อย":["ปัสสาวะบ่อย"],
    "ปัสสาวะแสบขัด":["ปัสสาวะแสบขัด",'ฉี่แสบขัด'],
    "ปัสสาวะเป็นเลือด":["ปัสสาวะเป็นเลือด",'ฉี่เป็นเลือด'],
    "อัณฑะโตผิดปกติ":["อัณฑะโตผิดปกติ","ไข่โตผิดปกติ","ไข่ผิดปกติ",'อัณฑะผิดปกติ','อัณฑะ'],
    "แผลเรื้อรัง":["แผลเรื้อรัง","เป็นแผล","แผล"],
    "ไฝหรือปานเปลี่ยนแปลง":["ไฝหรือปานเปลี่ยนแปลง","ไฝเปลี่ยนแปลง","ปานเปลี่ยนแปลง"],
    "มีตุ่มหรือก้อนใต้ผิวหนัง":["มีตุ่มหรือก้อนใต้ผิวหนัง","มีตุ่มใต้ผิวหนัง","มีก้อนใต้ผิวหนัง",'ก้อน','ตุ่ม','มีก้อน','มีตุ่ม','ตื่ง','มีตื่ง'],
    "ปวดศีรษะ":["ปวดศีรษะ","ปวดหัว"],
    "มองเห็นภาพผิดปกติ":["มองเห็นภาพผิดปกติ","มองไม่เห็น"],
    "ชัก":["ชัก"],
}

# %%
cancer_symptoms_en = {
    "Fatigue": ["Fatigue"],
    "Tiredness": ["Fatigue", "Tiredness", "Lethargy", "Shortness of breath"],
    "Itching": ["Itching", "Itching skin"],
    "Feverishness": ["Feverishness", "Fever"],
    "Pain": ["Pain", "Aches"],
    "Numbness": ["Numbness", "Tingling"],
    "Loss of appetite": ["Loss of appetite"],
    "Unexplained weight loss": ["Unexplained weight loss", "Weight loss", "Rapid weight loss"],
    "Chronic fever": ["Chronic fever", "Fever"],
    "Night sweats": ["Night sweats", "Sweating"],
    "Body aches": ["Body aches", "Aches"],
    "Swollen lymph nodes": ["Swollen lymph nodes"],
    "Stomach pain": ["Stomach pain"],
    "Sore throat": ["Sore throat"],
    "Swollen armpits": ["Swollen armpits"],
    "Back pain": ["Back pain"],
    "Darkened skin": ["Darkened skin"],
    "Breast pain": ["Breast pain"],
    "Bloating": ["Bloating", "Abdominal bloating", "Bloated"],
    "Chronic constipation": ["Chronic constipation", "Constipation"],
    "Indigestion": ["Indigestion"],
    "Difficulty swallowing": ["Difficulty swallowing", "Dysphagia"],
    "Chronic abdominal pain": ["Chronic abdominal pain"],
    "Vomiting blood": ["Vomiting blood", "Vomiting", "Emesis"],
    "Bloody stools": ["Bloody stools", "Blood in stool", "Melena"],
    "Chronic cough": ["Chronic cough", "Cough", "Persistent cough", "Dry cough"],
    "Coughing up blood": ["Coughing up blood"],
    "Hoarseness": ["Hoarseness"],
    "Shortness of breath": ["Shortness of breath", "Dyspnea"],
    "Chest pain": ["Chest pain"],
    "Vaginal bleeding": ["Vaginal bleeding", "Bleeding from vagina", "Abnormal bleeding"],
    "Vaginal discharge": ["Vaginal discharge"],
    "Frequent urination": ["Frequent urination"],
    "Urinary tract infection": ["Urinary tract infection", "Dysuria"],
    "Hematuria": ["Hematuria"],
    "Enlarged testicles": ["Enlarged testicles"],
    "Skin ulcers": ["Skin ulcers", "Ulcers"],
    "Changing moles or freckles": ["Changing moles or freckles"],
    "Lumps or bumps under the skin": ["Lumps or bumps under the skin"],
    "Headache": ["Headache"],
    "Vision problems": ["Vision problems"],
    "Seizures": ["Seizures"],
}

# %%
pd.DataFrame(list(symptoms.items()), columns=['Key', 'Values'])
# Out:
#                            Key  \
# 0                    อ่อนเพลีย
# 1                  เหนื่อยง่าย
# 2               คันเนื้อคันตัว
# 3                  มีอาการร้อน
# 4                 อาการเจ็บปวด
# 5                      อาการชา
# 6                   เบื่ออาหาร
# 7    น้ำหนักลดโดยไม่ทราบสาเหตุ
# 8                  ไข้เรื้อรัง
# 9          เหงื่อออกตอนกลางคืน
# 10                   ปวดเมื่อย
# 11      บวมหรือต่อมน้ำเหลืองโต
# 12                     ปวดท้อง
# 13                      เจ็บคอ
# 14                ปวดใต้รักแร้
# 15                      ปวดเอว
# 16              ผิวคล้ำผิดปกติ
# 17                  เจ็บเต้านม
# 18                     ท้องอืด
# 19             ท้องผูกเรื้อรัง
# 20                อาหารไม่ย่อย
# 21                   กลืนลำบาก
# 22             ปวดท้องเรื้อรัง
# 23           อาเจียนอาจมีเลือด
# 24           อุจจาระอาจมีเลือด
# 25                  ไอเรื้อรัง
# 26                 ไอเป็นเลือด
# 27                    เสียงแหบ
# 28                  หายใจลำบาก
# 29         เจ็บหรือเเน่นหน้าอก
# 30  เลือดออกผิดปกติจากช่องคลอด
# 31                ตกขาวผิดปกติ
# 32                 ปัสสาวะบ่อย
# 33               ปัสสาวะแสบขัด
# 34            ปัสสาวะเป็นเลือด
# 35              อัณฑะโตผิดปกติ
# 36                 แผลเรื้อรัง
# 37        ไฝหรือปานเปลี่ยนแปลง
# 38    มีตุ่มหรือก้อนใต้ผิวหนัง
# 39                    ปวดศีรษะ
# 40           มองเห็นภาพผิดปกติ
# 41                         ชัก
#
#                                                Values
# 0                                         [อ่อนเพลีย]
# 1           [เหนื่อยง่าย, เหนื่อย, เพลีย, เหนื่อยหอบ]
# 2            [คันเนื้อคันตัว, คัน, คันตัว, คันตามตัว]
# 3                          [ร้อน, อาการรัอน, ตัวร้อน]
# 4                       [เจ็บปวด, เจ็บ, อาการเจ็บปวด]
# 5                                       [อาการชา, ชา]
# 6                                        [เบื่ออาหาร]
# 7   [น้ำหนักลดโดยไม่ทราบสาเหตุ, น้ำหนักลด, น้ำหนัก...
# 8                         [ไข้เรื้อรัง, ไข้, เป็นไข้]
# 9   [เหงื่อออกตอนกลางคืน, เหงื่อออกตอนดึก, เหงื่อออก]
# 10                      [ปวดเมื่อยตามร่างกาย, เมื่อย]
# 11  [บวมหรือต่อมน้ำเหลืองโต, ต่อมน้ำเหลืองโต, บวมน...
# 12                                          [ปวดท้อง]
# 13                                           [เจ็บคอ]
# 14                          [ปวดใต้รักแร้, ปวดรักแร้]
# 15                                           [ปวดเอว]
# 16                                          [ผิวคล้ำ]
# 17                     [เจ็บเต้านม, เจ็บเต้า, เจ็บนม]
# 18                       [ท้องอืด, อาการอืดท้อง, อืด]
# 19                         [ท้องผูกเรื้อรัง, ท้องผูก]
# 20                                     [อาหารไม่ย่อย]
# 21               [กลืนลำบาก, กลืนอาหารลำบาก, กลืนยาก]
# 22                                  [ปวดท้องเรื้อรัง]
# 23                  [อาเจียนเป็นเลือด, อาเจียน, อ้วก]
# 24  [อุจจาระเป็นเลือด, อึเป็นเลือด, ขี้เป็นเลือด, ...
# 25              [ไอเรื้อรัง, ไอ, ไอต่อเนื่อง, ไอแห้ง]
# 26                                      [ไอเป็นเลือด]
# 27                                         [เสียงแหบ]
# 28                  [หายใจลำบาก, หายใจไม่อิ่ม, หายใจ]
# 29                          [เจ็บหน้าอก, เเน่นหน้าอก]
# 30  [เลือดออกผิดปกติจากช่องคลอด, เลือดออกจากช่องคล...
# 31                              [ตกขาวผิดปกติ, ตกขาว]
# 32                                      [ปัสสาวะบ่อย]
# 33                         [ปัสสาวะแสบขัด, ฉี่แสบขัด]
# 34                   [ปัสสาวะเป็นเลือด, ฉี่เป็นเลือด]
# 35  [อัณฑะโตผิดปกติ, ไข่โตผิดปกติ, ไข่ผิดปกติ, อัณ...
# 36                        [แผลเรื้อรัง, เป็นแผล, แผล]
# 37  [ไฝหรือปานเปลี่ยนแปลง, ไฝเปลี่ยนแปลง, ปานเปลี่...
# 38  [มีตุ่มหรือก้อนใต้ผิวหนัง, มีตุ่มใต้ผิวหนัง, ม...
# 39                                 [ปวดศีรษะ, ปวดหัว]
# 40                    [มองเห็นภาพผิดปกติ, มองไม่เห็น]
# 41                                              [ชัก]

# %%
len(data_value_EN)
# Out:
# 37

# %%
data_value_TH.reset_index()
# Out:
#     index                       name_cancarTH
# 0       0                 มะเร็งกระเพาะปัสสวะ
# 1       1              มะเร็งเยื่อบุโพรงมดลูก
# 2       2                      มะเร็งปากมดลูก
# 3       3                  มะเร็งเม็ดเลือดขาว
# 4       4                           มะเร็งตับ
# 5       5                       มะเร็งตับอ่อน
# 6       6                   มะเร็งต่อมลูกหมาก
# 7       7                มะเร็งกระเพาะปัสสาวะ
# 8       8                  มะเร็งกระเพาะอาหาร
# 9       9                     มะเร็งหลอดอาหาร
# 10     10                        มะเร็งเต้านม
# 11     11                           มะเร็งปอด
# 12     12                     มะเร็งลำไส้ใหญ่
# 13     13                        มะเร็งรังไข่
# 14     14                       มะเร็งช่องปาก
# 15     15                   มะเร็งต่อมไทรอยด์
# 16     16                 มะเร็งต่อมน้ำเหลือง
# 17     17                          มะเร็งสมอง
# 18     18                       มะเร็งผิวหนัง
# 19     19                         มะเร็งลำไส้
# 20     20                      มะเร็งท่อน้ำดี
# 21     21          มะเร็งลำไส้ใหญ่และทวารหนัก
# 22     22           มะเร็งผิวหนังชนิดเมลาโนมา
# 23     23  มะเร็งต่อมน้ำเหลืองชนิดนอนฮอดจ์กิน
# 24     24     มะเร็งเม็ดเลือดขาวชนิดเฉียบพลัน
# 25     25                        มะเร็งกระดูก
# 26     26         มะเร็งสมองและระบบประสาทกลาง
# 27     27                            มะเร็งไต
# 28     28                         มะเร็งมดลูก
# 29     29                      มะเร็งถุงน้ำดี
# 30     30                 มะเร็งกระดูกสันหลัง
# 31     31                         มะเร็งลูกตา
# 32     32               มะเร็งเยื่อบุช่องคลอด
# 33     33           มะเร็งเยื่อบุอวัยวะเพศชาย
# 34     34          มะเร็งเยื่อบุอวัยวะเพศหญิง
# 35     35                    มะเร็งต่อมหมวกไต
# 36     36                    มะเร็งต่อมน้ำลาย
# 37     37                  มะเร็งถุงน้ำรังไข่

# %%
data_value_TH = pd.DataFrame()
data_value_EN = pd.DataFrame()
data_symptoms_TH= pd.DataFrame(list(symptoms.items()), columns=['Key_symptoms_TH', 'Values_symptoms_TH'])
data_symptoms_EN= pd.DataFrame(list(cancer_symptoms_en.items()), columns=['Key_symptoms_EN', 'Valuessymptoms_EN'])
data_value_TH['name_cancarTH'] = name_cancar
data_value_EN['cancer_names_en'] = cancer_names_en
list_100 = list(range(0,100))
all_data['index'] = list_100
all_data = all_data.join(data_value_EN)
all_data = all_data.join(data_symptoms_TH)
all_data = all_data.join(data_symptoms_EN)
all_data
# Out:
#                          name_cancarTH                cancer_names_en  \
# 0                  มะเร็งกระเพาะปัสสวะ                 Bladder cancer
# 1               มะเร็งเยื่อบุโพรงมดลูก             Endometrial cancer
# 2                       มะเร็งปากมดลูก                Cervical cancer
# 3                   มะเร็งเม็ดเลือดขาว                       Leukemia
# 4                            มะเร็งตับ                   Liver cancer
# 5                        มะเร็งตับอ่อน              Pancreatic cancer
# 6                    มะเร็งต่อมลูกหมาก                Prostate cancer
# 7                 มะเร็งกระเพาะปัสสาวะ                 Stomach cancer
# 8                   มะเร็งกระเพาะอาหาร              Esophageal cancer
# 9                      มะเร็งหลอดอาหาร                  Breast cancer
# 10                        มะเร็งเต้านม                    Lung cancer
# 11                           มะเร็งปอด              Colorectal cancer
# 12                     มะเร็งลำไส้ใหญ่                 Ovarian cancer
# 13                        มะเร็งรังไข่                    Oral cancer
# 14                       มะเร็งช่องปาก                 Thyroid cancer
# 15                   มะเร็งต่อมไทรอยด์                       Lymphoma
# 16                 มะเร็งต่อมน้ำเหลือง                   Brain cancer
# 17                          มะเร็งสมอง                    Skin cancer
# 18                       มะเร็งผิวหนัง              Intestinal cancer
# 19                         มะเร็งลำไส้               Bile duct cancer
# 20                      มะเร็งท่อน้ำดี              Colorectal cancer
# 21          มะเร็งลำไส้ใหญ่และทวารหนัก                       Melanoma
# 22           มะเร็งผิวหนังชนิดเมลาโนมา               Hodgkin lymphoma
# 23  มะเร็งต่อมน้ำเหลืองชนิดนอนฮอดจ์กิน                 Acute leukemia
# 24     มะเร็งเม็ดเลือดขาวชนิดเฉียบพลัน                    Bone cancer
# 25                        มะเร็งกระดูก  Central nervous system cancer
# 26         มะเร็งสมองและระบบประสาทกลาง                  Kidney cancer
# 27                            มะเร็งไต                 Uterine cancer
# 28                         มะเร็งมดลูก             Gallbladder cancer
# 29                      มะเร็งถุงน้ำดี             Spinal cord cancer
# 30                 มะเร็งกระดูกสันหลัง                     Eye cancer
# 31                         มะเร็งลูกตา                 Vaginal cancer
# 32               มะเร็งเยื่อบุช่องคลอด                  Penile cancer
# 33           มะเร็งเยื่อบุอวัยวะเพศชาย                  Vulvar cancer
# 34          มะเร็งเยื่อบุอวัยวะเพศหญิง           Adrenal gland cancer
# 35                    มะเร็งต่อมหมวกไต          Salivary gland cancer
# 36                    มะเร็งต่อมน้ำลาย            Ovarian cyst cancer
# 37                  มะเร็งถุงน้ำรังไข่                            NaN
#
#                Key_symptoms_TH  \
# 0                    อ่อนเพลีย
# 1                  เหนื่อยง่าย
# 2               คันเนื้อคันตัว
# 3                  มีอาการร้อน
# 4                 อาการเจ็บปวด
# 5                      อาการชา
# 6                   เบื่ออาหาร
# 7    น้ำหนักลดโดยไม่ทราบสาเหตุ
# 8                  ไข้เรื้อรัง
# 9          เหงื่อออกตอนกลางคืน
# 10                   ปวดเมื่อย
# 11      บวมหรือต่อมน้ำเหลืองโต
# 12                     ปวดท้อง
# 13                      เจ็บคอ
# 14                ปวดใต้รักแร้
# 15                      ปวดเอว
# 16              ผิวคล้ำผิดปกติ
# 17                  เจ็บเต้านม
# 18                     ท้องอืด
# 19             ท้องผูกเรื้อรัง
# 20                อาหารไม่ย่อย
# 21                   กลืนลำบาก
# 22             ปวดท้องเรื้อรัง
# 23           อาเจียนอาจมีเลือด
# 24           อุจจาระอาจมีเลือด
# 25                  ไอเรื้อรัง
# 26                 ไอเป็นเลือด
# 27                    เสียงแหบ
# 28                  หายใจลำบาก
# 29         เจ็บหรือเเน่นหน้าอก
# 30  เลือดออกผิดปกติจากช่องคลอด
# 31                ตกขาวผิดปกติ
# 32                 ปัสสาวะบ่อย
# 33               ปัสสาวะแสบขัด
# 34            ปัสสาวะเป็นเลือด
# 35              อัณฑะโตผิดปกติ
# 36                 แผลเรื้อรัง
# 37        ไฝหรือปานเปลี่ยนแปลง
#
#                                    Values_symptoms_TH  \
# 0                                         [อ่อนเพลีย]
# 1           [เหนื่อยง่าย, เหนื่อย, เพลีย, เหนื่อยหอบ]
# 2            [คันเนื้อคันตัว, คัน, คันตัว, คันตามตัว]
# 3                          [ร้อน, อาการรัอน, ตัวร้อน]
# 4                       [เจ็บปวด, เจ็บ, อาการเจ็บปวด]
# 5                                       [อาการชา, ชา]
# 6                                        [เบื่ออาหาร]
# 7   [น้ำหนักลดโดยไม่ทราบสาเหตุ, น้ำหนักลด, น้ำหนัก...
# 8                         [ไข้เรื้อรัง, ไข้, เป็นไข้]
# 9   [เหงื่อออกตอนกลางคืน, เหงื่อออกตอนดึก, เหงื่อออก]
# 10                      [ปวดเมื่อยตามร่างกาย, เมื่อย]
# 11  [บวมหรือต่อมน้ำเหลืองโต, ต่อมน้ำเหลืองโต, บวมน...
# 12                                          [ปวดท้อง]
# 13                                           [เจ็บคอ]
# 14                          [ปวดใต้รักแร้, ปวดรักแร้]
# 15                                           [ปวดเอว]
# 16                                          [ผิวคล้ำ]
# 17                     [เจ็บเต้านม, เจ็บเต้า, เจ็บนม]
# 18                       [ท้องอืด, อาการอืดท้อง, อืด]
# 19                         [ท้องผูกเรื้อรัง, ท้องผูก]
# 20                                     [อาหารไม่ย่อย]
# 21               [กลืนลำบาก, กลืนอาหารลำบาก, กลืนยาก]
# 22                                  [ปวดท้องเรื้อรัง]
# 23                  [อาเจียนเป็นเลือด, อาเจียน, อ้วก]
# 24  [อุจจาระเป็นเลือด, อึเป็นเลือด, ขี้เป็นเลือด, ...
# 25              [ไอเรื้อรัง, ไอ, ไอต่อเนื่อง, ไอแห้ง]
# 26                                      [ไอเป็นเลือด]
# 27                                         [เสียงแหบ]
# 28                  [หายใจลำบาก, หายใจไม่อิ่ม, หายใจ]
# 29                          [เจ็บหน้าอก, เเน่นหน้าอก]
# 30  [เลือดออกผิดปกติจากช่องคลอด, เลือดออกจากช่องคล...
# 31                              [ตกขาวผิดปกติ, ตกขาว]
# 32                                      [ปัสสาวะบ่อย]
# 33                         [ปัสสาวะแสบขัด, ฉี่แสบขัด]
# 34                   [ปัสสาวะเป็นเลือด, ฉี่เป็นเลือด]
# 35  [อัณฑะโตผิดปกติ, ไข่โตผิดปกติ, ไข่ผิดปกติ, อัณ...
# 36                        [แผลเรื้อรัง, เป็นแผล, แผล]
# 37  [ไฝหรือปานเปลี่ยนแปลง, ไฝเปลี่ยนแปลง, ปานเปลี่...
#
#                Key_symptoms_EN  \
# 0                      Fatigue
# 1                    Tiredness
# 2                      Itching
# 3                 Feverishness
# 4                         Pain
# 5                     Numbness
# 6             Loss of appetite
# 7      Unexplained weight loss
# 8                Chronic fever
# 9                 Night sweats
# 10                  Body aches
# 11         Swollen lymph nodes
# 12                Stomach pain
# 13                 Sore throat
# 14             Swollen armpits
# 15                   Back pain
# 16               Darkened skin
# 17                 Breast pain
# 18                    Bloating
# 19        Chronic constipation
# 20                 Indigestion
# 21       Difficulty swallowing
# 22      Chronic abdominal pain
# 23              Vomiting blood
# 24               Bloody stools
# 25               Chronic cough
# 26           Coughing up blood
# 27                  Hoarseness
# 28         Shortness of breath
# 29                  Chest pain
# 30            Vaginal bleeding
# 31           Vaginal discharge
# 32          Frequent urination
# 33     Urinary tract infection
# 34                   Hematuria
# 35          Enlarged testicles
# 36                 Skin ulcers
# 37  Changing moles or freckles
#
#                                     Valuessymptoms_EN
# 0                                           [Fatigue]
# 1   [Fatigue, Tiredness, Lethargy, Shortness of br...
# 2                             [Itching, Itching skin]
# 3                               [Feverishness, Fever]
# 4                                       [Pain, Aches]
# 5                                [Numbness, Tingling]
# 6                                  [Loss of appetite]
# 7   [Unexplained weight loss, Weight loss, Rapid w...
# 8                              [Chronic fever, Fever]
# 9                            [Night sweats, Sweating]
# 10                                [Body aches, Aches]
# 11                              [Swollen lymph nodes]
# 12                                     [Stomach pain]
# 13                                      [Sore throat]
# 14                                  [Swollen armpits]
# 15                                        [Back pain]
# 16                                    [Darkened skin]
# 17                                      [Breast pain]
# 18            [Bloating, Abdominal bloating, Bloated]
# 19               [Chronic constipation, Constipation]
# 20                                      [Indigestion]
# 21                 [Difficulty swallowing, Dysphagia]
# 22                           [Chronic abdominal pain]
# 23                 [Vomiting blood, Vomiting, Emesis]
# 24            [Bloody stools, Blood in stool, Melena]
# 25  [Chronic cough, Cough, Persistent cough, Dry c...
# 26                                [Coughing up blood]
# 27                                       [Hoarseness]
# 28                     [Shortness of breath, Dyspnea]
# 29                                       [Chest pain]
# 30  [Vaginal bleeding, Bleeding from vagina, Abnor...
# 31                                [Vaginal discharge]
# 32                               [Frequent urination]
# 33                 [Urinary tract infection, Dysuria]
# 34                                        [Hematuria]
# 35                               [Enlarged testicles]
# 36                              [Skin ulcers, Ulcers]
# 37                       [Changing moles or freckles]
