# %% [markdown]
# <a href="https://colab.research.google.com/github/MOOwuttichai/Cancer_Social_Listening/blob/main/%E0%B8%94%E0%B8%B6%E0%B8%87%20comment%20%E0%B8%88%E0%B8%B2%E0%B8%81FB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install facebook_scraper requests pandas

# %%
import facebook_scraper as fs
import requests
from http.cookiejar import CookieJar
import pandas as pd

# %%
# Create a CookieJar object
cookie_jar = CookieJar()
# Exported cookies from the "EditThisCookie" extension
cookies = [

{
    "domain": ".facebook.com",
    "expirationDate": 1745423507,
    "hostOnly": False,
    "httpOnly": False,
    "name": "c_user",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "100003719958826",
    "id": 1
},
{
    "domain": ".facebook.com",
    "expirationDate": 1738211708,
    "hostOnly": False,
    "httpOnly": True,
    "name": "datr",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "1pSGYcNtfrSHBPGttmSAJWje",
    "id": 2
},
{
    "domain": ".facebook.com",
    "expirationDate": 1714493314,
    "hostOnly": False,
    "httpOnly": False,
    "name": "dpr",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "1.25",
    "id": 3
},
{
    "domain": ".facebook.com",
    "expirationDate": 1721663507,
    "hostOnly": False,
    "httpOnly": True,
    "name": "fr",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "1SCElxiNVsrjukqSG.AWV1NrygrYp5nKzZTQ7ARwElTq0.BmJ9kS..AAA.0.0.BmJ9kS.AWWLz25SXcs",
    "id": 4
},
{
    "domain": ".facebook.com",
    "hostOnly": False,
    "httpOnly": False,
    "name": "presence",
    "path": "/",
    "sameSite": "unspecified",
    "secure": True,
    "session": True,
    "storeId": "0",
    "value": "C%7B%22t3%22%3A%5B%7B%22o%22%3A0%2C%22i%22%3A%22sc.6924686160950276%22%7D%5D%2C%22utc3%22%3A1713888518552%2C%22v%22%3A1%7D",
    "id": 5
},
{
    "domain": ".facebook.com",
    "expirationDate": 1748072952,
    "hostOnly": False,
    "httpOnly": True,
    "name": "ps_l",
    "path": "/",
    "sameSite": "lax",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "1",
    "id": 6
},
{
    "domain": ".facebook.com",
    "expirationDate": 1748072952,
    "hostOnly": False,
    "httpOnly": True,
    "name": "ps_n",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "1",
    "id": 7
},
{
    "domain": ".facebook.com",
    "expirationDate": 1744216708,
    "hostOnly": False,
    "httpOnly": True,
    "name": "sb",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "1pSGYbKrJXTJmGzQANXZs9Oo",
    "id": 8
},
{
    "domain": ".facebook.com",
    "expirationDate": 1714493314,
    "hostOnly": False,
    "httpOnly": False,
    "name": "wd",
    "path": "/",
    "sameSite": "lax",
    "secure": True,
    "session": False,
    "storeId": "0",
    "value": "1536x754",
    "id": 9
},
{
    "domain": ".facebook.com",
    "hostOnly": False,
    "httpOnly": True,
    "name": "xs",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": True,
    "session": True,
    "storeId": "0",
    "value": "39%3AQ1Oo340WR6wX6Q%3A2%3A1709656706%3A-1%3A11932%3A%3AAcVvH8l9T0__FasOCiVrdmGd2GL0x7xYiDbZG3YnO7ME",
    "id": 10
}
]

# Convert the cookies to a CookieJar object
for cookie in cookies:
    c = requests.cookies.create_cookie(
        domain=cookie["domain"],
        name=cookie["name"],
        value=cookie["value"],
        path=cookie["path"],
        secure=cookie["secure"],
        expires=cookie.get("expirationDate"),
        rest={
            "HttpOnly": cookie["httpOnly"],
            "SameSite": cookie["sameSite"],
        },
    )
    cookie_jar.set_cookie(c)

# %%
# Define the post ID
POST_ID = 1931925450566523

# Define the maximum number of comments to download
MAX_COMMENTS = 1000

# Get the post (this gives a generator)
gen = fs.get_posts(
    post_urls=[POST_ID],
    options={"comments": MAX_COMMENTS, "progress": True},
    cookies=cookie_jar
)

# Get the first element of the generator, which is the post we requested
post = next(gen)

# Extract the comments from the post
comments = post['comments_full']
# Out:
# /usr/local/lib/python3.10/dist-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# ---------------------------------------------------------------------------
# LoginRequired                             Traceback (most recent call last)
# <ipython-input-19-35bef88f56c7> in <cell line: 15>()
#      13
#      14 # Get the first element of the generator, which is the post we requested
# ---> 15 post = next(gen)
#      16
#      17 # Extract the comments from the post
#
# /usr/local/lib/python3.10/dist-packages/facebook_scraper/facebook_scraper.py in get_posts_by_url(self, post_urls, options, remove_source)
#     127             post = {"original_request_url": post_url, "post_url": url}
#     128             logger.debug(f"Requesting page from: {url}")
# --> 129             response = self.get(url)
#     130             options["response_url"] = response.url
# ...

# %%
# Iterate through comments and add them to the DataFrame
for comment in comments:
    # Extract comment information
    comment_id = comment['comment_id']
    comment_text = comment['comment_text']

#     # Create a new row with the comment information
#     new_row = {'comment_id': comment_id, 'comment_text': comment_text}

#     # Append the new row to the DataFrame
#     commentdf = pd.DataFrame(new_row)

# # Save the resulting DataFrame as a CSV file
# commentdf.to_csv("t1_facebook_comment.csv", index=False)

# %%
comments
# Out:
# [{'comment_id': '1932280870530981',
#   'comment_url': 'https://facebook.com/1932280870530981',
#   'commenter_id': '100028908137252',
#   'commenter_url': 'https://facebook.com/pun.pumiput?groupid=1733193060439764&eav=AfYJg0VHioDlioCl2GZrcllR_xFJj_G1JVgud04cmCkhY-t15WWVKmY6bsr6P3G4LBc&refid=18&__tn__=R&paipv=0',
#   'commenter_name': 'Pun Punnapat',
#   'commenter_meta': None,
#   'comment_text': 'เกินไปเลยอะ',
#   'comment_time': datetime.datetime(2024, 4, 23, 23, 0),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '1932281137197621',
#   'comment_url': 'https://facebook.com/1932281137197621',
#   'commenter_id': '100004066004353',
#   'commenter_url': 'https://facebook.com/profile.php?id=100004066004353&groupid=1733193060439764&eav=AfbUqRw21xhb55mAHZKbxpuUk_2F7KQ3mMTe_9VXiiaY5eKNOPiN8Ur7S3ztagGfRL4&refid=18&__tn__=R&paipv=0',
# ...
